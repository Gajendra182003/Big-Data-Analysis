# %% [markdown]
# <a href="https://colab.research.google.com/github/Gajendra182003/BDA_Assignments/blob/main/28_feb_2026_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Function:
Code is written away from the main script

when needed, called from the main script.

When called the function gets executed. Once over control comes back to the main script.

+ve:
Resuse(Coded once called n times. )
modular coding(Breaking a large logic into sub-logic and sub-quotes )
faster development(It is a combination of reuse and modular coding. )
			Chinese food
Easy of Upgradation
(Change new function with old function and add new functionality. )

# %%
#syntax:

def <name>():
    #body

# %%
def welcome(name):
    print(f"{name},welcome home")

# %%
welcome("amita")
# Out:
# amita,welcome home

# %%
#Document string is optional but very commonly used in industry, telling the user what the function is about.

# %%
def welcome(name):
    '''Input:Name(String) Output:prints welcome with name(String)'''
    print(f"{name},welcome home")

# %%
#General design of Modular Coding is taking data from the user or the menscript, performing processing, and returning the answer.

# %%
#First version takes the data but prints the answer.
def addition(parameter1,parameter2):
    print(f"{parameter1}+{parameter2}={parameter1+parameter2}")

# %%
addition(10,20)
#By default in Python overloading is supported for respective operators.
addition(10.33,20.11)
addition("Amar ","Panchal")
# Out:
# 10+20=30
# 10.33+20.11=30.439999999999998
# Amar +Panchal=Amar Panchal

# %%
#Second version, more use in industry, takes data, processes it, and returns the answer.
def minimum(n1,n2):
    min_is=n1 if n1<n2 else n2
    return min_is

# %%
#main script:
no1,no2=map(int,input("Enter 2 numbers:").split())
#print(f"{no1} @{id(no1)}\n{no2} @{id(no2)}")
print(f"minimum is:{minimum(no1,no2)}")
# Out:
# Enter 2 numbers:3 9
# minimum is:3

# %%
#main script:
no1,no2=map(int,input("Enter 2 numbers:").split())
#print(f"{no1} @{id(no1)}\n{no2} @{id(no2)}")
answer=minimum(no1,no2)
print(f"minimum is:{answer}")
# Out:
# Enter 2 numbers:33 9
# minimum is:9

# %%
def minimum(n1,n2):
    min_is=n1 if n1<n2 else n2
    return min_is
#Without modifying the function given, write a code to find the minimum of four numbers.

# %%
#3,55,7,1
print(f"Minimum is:{minimum(minimum(3,55),minimum(7,1))}")
                        #             3            1
                        #                    1
# Out:
# Minimum is:1

# %%
#Accept length and breadth from the main script and return the area of a rectangle.

def area(length,breadth):
    return length*breadth

# %%
length,breadth=map(float,input("Enter length and breadth\n").split())
print(f"Area of reactangle is:{area(length,breadth)}")
# Out:
# Enter length and breadth
# 34.1 76
# Area of reactangle is:2591.6

# %%
print(f"Area of reactangle is:{area(float(input("Enter l:")),float(input("Enter b:")))}")
# Out:
# Enter l:22
# Enter b:66
# Area of reactangle is:1452.0

# %%
#Nested Function Call : a function calling another function
def copy_right():
    print("coded by @amar.career")
def inr_to_usd(inr):
    copy_right()#nested call
    return inr/90.1
#Nesting of function is generally performed either for security or for making a standard call for some kind of information sharing.

# %%
print("this is main script:")
inr=float(input("Enter amount in inr:"))
print(f"{inr}INR is {inr_to_usd(inr)}USD")
# Out:
# this is main script:
# Enter amount in inr:120000
# coded by @amar.career
# 120000.0INR is 1331.8534961154273USD

# %%
#Function can return and accept multiple values but changes done to primitive types are only seen in the function.
def swapper(no1,no2):
    print(f"\t In Function no1:{no1} no2:{no2}")
    no1,no2=no2,no1
    print(f"\t In Function no1:{no1} no2:{no2}")
 #By default the function creates a local copy of the data, operates on the data, and these local copies are destroyed when the function gives back control to the mempath.(dream theory)

# %%
n1,n2=10,20
print("In Main..................")
print(f"In Main n1:{n1} n2:{n2}")
swapper(n1,n2)
print(f"In Main n1:{n1} n2:{n2}")
# Out:
# In Main..................
# In Main n1:10 n2:20
# 	 In Function no1:10 no2:20
# 	 In Function no1:20 no2:10
# In Main n1:10 n2:20

# %%
#Key-Value Parameter : you can give parameters in any order but they are taken correctly if given in a key-value pair.
def intro(name,native):
    print(f"oh hi {name}, so you are from {native}")

# %%
intro("amar","mumbai")
# Out:
# oh hi amar, so you are from mumbai

# %%
intro("gujrat","jigneshhhh")
# Out:
# oh hi gujrat, so you are from jigneshhhh

# %%
intro(native="gujrat",name="jigneshhhh")
# Out:
# oh hi jigneshhhh, so you are from gujrat

# %%
#Default Value Parameter : this value is used if and only if the user will not give any data. If the user provides data, that data would be taken.
def intro(name,native="india"):
    print(f"oh hi {name}, so you are from {native}")

# %%
intro("amar","mumbai")
# Out:
# oh hi amar, so you are from mumbai

# %%
intro("amar")
# Out:
# oh hi amar, so you are from india

# %%
#Variable size parameter or n-value parameter
#Very commonly used when the user is unsure about the number of parameters to be given.
def my_hobbies(*hobbies):
    print(f"i have total {len(hobbies)}")
    print(f"my hobbies are:{hobbies}")

# %%
def my_hobbies(*hobbies):
    print(f"i have total {len(hobbies)}")
    for h in hobbies:
        if h=="sketch":
            print("artist")
        elif h=="sleep":
            print("panda")
        print("->",h)

# %%
my_hobbies("sketch","write","travel","code")
# Out:
# i have total 4
# artist
# -> sketch
# -> write
# -> travel
# -> code

# %%
my_hobbies("eat","sleep")
# Out:
# i have total 2
# -> eat
# panda
# -> sleep

# %%
my_hobbies("over think")
# Out:
# i have total 1
# my hobbies are:('over think',)

# %% [markdown]
# 🚗 Problem: “Car Rental Cost Estimator”
# 🎯 Problem Statement
#
# Create a function that calculates rental cost.
#
# 📌 Requirements:
#
# Parameters:
#
# Number of days
#
# Cost per day
#
# Default insurance charge per day = 100
#
# Calculate total cost including insurance.
#
# If rental days > 7, give 5% discount on total.
#
# 💡 Sample Call:
# calculate_rent(5, 1000)
# 📤 Expected Output:
# Days: 5
# Rent Cost: 5000
# Insurance: 500
# Total Payable: 5500
# <br>💡 Sample 2:
# calculate_rent(10, 1000)
# Days: 10
# Rent Cost: 10000
# Insurance: 1000
# Discount Applied: 550
# Final Payable: 10450

# %%
def Car_Rental_Cost_Estimator(days,rental,insurance_charges=100):
    disscount=0
    if days>7:
        disscount=0.05
    total=days*rental+days*insurance_charges
    return total-(disscount*total)

# %%
Car_Rental_Cost_Estimator(5, 1000,200)
# Out:
# 6000

# %% [markdown]
# Problem: “Startup Expense Tracker”
# 🎯 Problem Statement
#
# Create a function that calculates total business expenses.
#
# 📌 Requirements:
#
# Accept business name (mandatory parameter)
#
# Accept any number of expenses using *kwargs
#
# Print each expense category with amount
#
# Print total expense
#
# If no expenses are given, print "No expenses recorded."
# office=15000
# staff=150000
# food=10000
# tea=2000
# ads=100000

# %%
def startup_expens_tracker(name,*expenses):
    total_expense=0
    if len(expenses)==0:
        return f"{name}:No expenses recorded."
    else:
        print(f"Total expenses are:{len(expenses)}")
    for e in expenses:
        if e=="office":
            total_expense+=15000
        elif e=="staff":
            total_expense+=150000
        elif e=="food":
            total_expense+=10000
        elif e=="tea":
            total_expense+=2000
        elif e=="ads":
            total_expense+=100000
    return f"{name}:{total_expense}"

# %%
startup_expens_tracker("CDAC","ads","office","tea")
# Out:
# Total expenses are:3
# 'CDAC:117000'

# %%
startup_expens_tracker("apna_startup")
# Out:
# 'apna_startup:No expenses recorded.'

# %% [markdown]
# function:
#
# def <name>(<parameters>):
# 	'''document string '''
# 	#code
#
#
# return:Statement used to give data from the function to the script.
# There can be multiple written but any one will only get executed.
#
# (parameter1,parameter2....)
# Parameters are local copies to the function. Changes done will only be seen within the function. Outside the function they are not valid.
#
# (identifier=value...)#tag
# Concept is called Key Value Parameter. It can be given in any order but mapping would be identifier to the given value.
#
# (parameter1,parameter2,parameter3=value)
# Default value parameter, always to be on the right, used when the user does not pass any thing.
#
#
# Rule of writing a function and calling it:
# 1. it should be declared before and
# 2 then only called;
# Note :reverse is not allowed.
#
# normal working:
#
# u create main that takes values(reads)
# this part calls function(pre-written) and passes data by value to function
# pass by value:Local copy of passed data is created and can be manipulated but the original will not be affected. ex swapper()

# %%
#function polymophism
A function can be given different aliases in Python, called function polymorphism, used in the concept of a decorator.

# %%
def welcome(name):
    '''Input:Name(String) Output:prints welcome with name(String)'''
    print(f"{name},welcome home")

# %%
hi=welcome#Alternative identifier to call exact function

# %%
hi("amar")
# Out:
# amar,welcome home

# %%
wc=hi

# %%
wc("amar")
# Out:
# amar,welcome home

# %%
''''
#decorator:
Method of packing old function in a new way of calling.
Basic reason: evolution or way of calling changing over time.
#Major use of the concept like decorator is on the OTT platform for multi-language support.
'''
def english(name):
    print(f"hi my dear friend {name}")
def hindi(name):
    print(f"हाय मेरे प्यारे दोस्त {name}")
def marathi(name):
    print(f"नमस्कार माझ्या प्रिय मित्रा {name}")

def ott_app(name,lang=hindi):
    lang(name)

# %%
ott_app("amar",english)
ott_app("amar",marathi)
ott_app("amar",hindi)
ott_app("amar")
# Out:
# hi my dear friend amar
# नमस्कार माझ्या प्रिय मित्रा amar
# हाय मेरे प्यारे दोस्त amar
# हाय मेरे प्यारे दोस्त amar

# %%
#Generator : a specialized written function which will run in parts every time a user asks for the next value.
#Best example to give: coffee vending machine. On a button press the entire process is repeated. A coffee is generated and then it stops.

# %%
def counter():
    for i in range(1,10,1):
        print(i)

# %%
counter()
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
def counter():
    for i in range(1,10,1):
        yield i#Pauses execution of function till next
#Yield statement can return a value and pause. Do not use return in generators.

# %%
count=counter()

# %%
print("now count is:",next(count))
# Out:
# now count is: 9

# %%
#Recursion :
#A way where a function calls itself.
#Comment on recursion:+ve and -ve both
#Recursion makes code look smaller, hence more readable.(+ve)
#It makes the program run slower, consumes more memory, and is very complex to understand at a time. (-ve)

# %%
def factorial(no):
    if no==1:
        return 1
    else:
        return no*factorial(no-1)

# %%
factorial(4)
# Out:
# 24

# %%
#Using recursion calculate GCD of two numbers.
#Following are the rules:
#If number one is perfectly divisible by number two, then number two is GCD.
#Otherwise let number one store number two and let number two store the remainder between number one and number two.
def GCD(no1,no2):
    if no1%no2==0:
        return no2
    else:
        return GCD(no2,no1%no2)

# %%
GCD(18,16)
# Out:
# 2

# %%
#Global and local variables in Python.
#Variables declared in open space are global.
#Variables declared in some control structure are local.
#When a global and local variable have exactly the same identifier, preference is given to the local variable.
# Out:
# main script
# this is x:100
# main script ends

# %%
#Global data can be accessed within the function.
x=100#global
def my_print():
    print(f"this is x:{x}")


print("main script")
my_print()
print("main script ends")
# Out:
# main script
# this is x:100
# main script ends

# %%
#In order to allow accessing of global data for manipulation, we will use the keyword global.
x=100#global
def my_print():
    global x
    x=x+10
    print(f"\tInFunction this is x:{x}")


print("main script")
print(f"Main this is x:{x}")
my_print()
print(f"Main this is x:{x}")
print("main script ends")
# Out:
# main script
# Main this is x:100
# 	InFunction this is x:110
# Main this is x:110
# main script ends

# %%
#In Python, if a variable is declared within a block,
#it only exists until the end of that block.
a=10
if True:
    b=20
    if True:
        c=30
        print(a,b,c)
    print(a,b)
print(a)
# Out:
# 10 20 30
# 10 20 30

# %%
#If we have exact global and local variable, then the local variable will give a higher preference than the global.

x=100
def my_print():
    x=1000
    print(f"\tInFunction this is x:{x}")
    global x:
    print(f"\tInFunction this is x:{x}")


print("main script")
print(f"Main :this is x:{x}")
my_print()
print("Main script ends")
# Out:
# main script
# Main :this is x:100
# 	InFunction this is x:1000
# Main script ends

# %%
for i in range(1,4):
    print(i)
for i in range(10,14):
    print(i)
# Out:
# 1
# 2
# 3
# 10
# 11
# 12
# 13

# %% [markdown]
# <h1>🔥 10 Real-Life Function-Based Mini Projects (No Code)</h1>
#
# <hr>
#
# <h2>1️⃣ ATM Banking System</h2>
# <b>Problem Definition:</b><br>
# Create a menu-driven ATM system using functions.<br>
# Operations:<br>
# • Check Balance<br>
# • Deposit Money<br>
# • Withdraw Money<br>
# • Exit<br><br>
# Do not allow withdrawal if balance is insufficient.<br>
# System runs in loop until user exits.<br><br>
#
# <b>Sample Input:</b><br>
# 1<br>
# 2 (Deposit 5000)<br>
# 3 (Withdraw 2000)<br>
# 4<br><br>
#
# <b>Sample Output:</b><br>
# Current Balance: 10000<br>
# Amount Deposited Successfully<br>
# Amount Withdrawn Successfully<br>
# Thank you for using ATM
#
# <hr>
#
# <h2>2️⃣ Student Result Management</h2>
# <b>Problem Definition:</b><br>
# Take marks of 5 subjects.<br>
# Create functions to calculate:<br>
# • Total<br>
# • Percentage<br>
# • Grade<br><br>
#
# Grade Rules:<br>
# >= 75 → Distinction<br>
# >= 60 → First Class<br>
# >= 50 → Second Class<br>
# >= 40 → Pass<br>
# < 40 → Fail<br><br>
#
# <b>Sample Input:</b><br>
# 78 67 89 56 90<br><br>
#
# <b>Sample Output:</b><br>
# Total: 380<br>
# Percentage: 76%<br>
# Grade: Distinction
#
# <hr>
#
# <h2>3️⃣ Online Shopping Bill Generator</h2>
# <b>Problem Definition:</b><br>
# User can add multiple items.<br>
# Functions required:<br>
# • Add Item<br>
# • Calculate Total<br>
# • Apply Discount (10% if total > 5000)<br>
# • Print Final Bill<br><br>
#
# <b>Sample Input:</b><br>
# Laptop 45000<br>
# Mouse 1000<br><br>
#
# <b>Sample Output:</b><br>
# Total: 46000<br>
# Discount: 4600<br>
# Final Amount: 41400
#
# <hr>
#
# <h2>4️⃣ Electricity Bill Calculator</h2>
# <b>Problem Definition:</b><br>
# 0–100 units → ₹5 per unit<br>
# 101–200 → ₹7 per unit<br>
# Above 200 → ₹10 per unit<br><br>
# Use function to calculate total bill.<br><br>
#
# <b>Sample Input:</b><br>
# 250<br><br>
#
# <b>Sample Output:</b><br>
# Total Bill: ₹1950
#
# <hr>
#
# <h2>5️⃣ Library Fine Calculator</h2>
# <b>Problem Definition:</b><br>
# 1–5 days → ₹10/day<br>
# 6–10 days → ₹20/day<br>
# Above 10 → ₹50/day<br><br>
# Create function to calculate fine.<br><br>
#
# <b>Sample Input:</b><br>
# 12<br><br>
#
# <b>Sample Output:</b><br>
# Total Fine: ₹600
#
# <hr>
#
# <h2>6️⃣ Employee Salary Slip Generator</h2>
# <b>Problem Definition:</b><br>
# Input Basic Salary.<br>
# Calculate using functions:<br>
# HRA = 20%<br>
# DA = 10%<br>
# Tax = 5% if salary > 50000<br><br>
#
# <b>Sample Input:</b><br>
# 60000<br><br>
#
# <b>Sample Output:</b><br>
# Gross Salary: 78000<br>
# Tax Deducted: 3900<br>
# Net Salary: 74100
#
# <hr>
#
# <h2>7️⃣ Password Strength Checker</h2>
# <b>Problem Definition:</b><br>
# Password must:<br>
# • Have at least 8 characters<br>
# • Contain number<br>
# • Contain uppercase letter<br><br>
# Return Strong or Weak using function.<br><br>
#
# <b>Sample Input:</b><br>
# Amar@123<br><br>
#
# <b>Sample Output:</b><br>
# Password Strength: Strong
#
# <hr>
#
# <h2>8️⃣ Train Ticket Booking</h2>
# <b>Problem Definition:</b><br>
# Ticket price ₹500 each.<br>
# If tickets > 5 → 10% discount.<br><br>
# Use functions to calculate total and discount.<br><br>
#
# <b>Sample Input:</b><br>
# 7<br><br>
#
# <b>Sample Output:</b><br>
# Total: 3500<br>
# Discount: 350<br>
# Final Amount: 3150
#
# <hr>
#
# <h2>9️⃣ Loan EMI Eligibility Checker</h2>
# <b>Problem Definition:</b><br>
# EMI must not exceed 40% of salary.<br>
# Create function to validate eligibility.<br><br>
#
# <b>Sample Input:</b><br>
# Salary: 50000<br>
# EMI: 25000<br><br>
#
# <b>Sample Output:</b><br>
# Loan Not Approved
#
# <hr>
#
# <h2>🔟 Movie Ticket Booking with Age Validation</h2>
# <b>Problem Definition:</b><br>
# If age < 18 → Not allowed for adult movie.<br>
# Ticket price ₹300 each.<br><br>
# Use functions for validation and total calculation.<br><br>
#
# <b>Sample Input:</b><br>
# Age: 22<br>
# Tickets: 3<br><br>
#
# <b>Sample Output:</b><br>
# Booking Successful<br>
# Total Amount: ₹900
#
# <hr>
#
# <h3>⚡ Requirement:</h3>
# • Every project must use functions<br>
# • Use loops for repetition<br>
# • Use conditions for decision making<br>
# • Keep modular structure<br>
# • No global messy logic<br>
#
# <h3>🎯 Goal:</h3>
# Write clean, interview-ready logic.<br>
# Think modular. Think scalable. Think structured.

# %%
'''Problem Definition:
0–100 units → ₹5 per unit
101–200 → ₹7 per unit
Above 200 → ₹10 per unit

Use function to calculate total bill.

Sample Input:
250


Sample Output:
Total Bill: ₹1950'''
#From the men you will only accept unit pass it to function. Function will return bin amount.
def calculate_bill(units):
    max_unit=mid_unit=min_unit=0.0
    if units>200:
        max_unit=units-200
        units=units-max_unit
    if 200>=units>100:#170
        mid_unit=units-100
        units=units-mid_unit
    if 100>=units>0:#80
        min_unit=units
    return max_unit*10+mid_unit*7+min_unit*5

units=int(input("Enter units:"))
total_bill_amount=calculate_bill(units)
print(f"Total bill amount {total_bill_amount} of {units}")
# Out:
# Enter units:250
# Total bill amount 1700 of 250

# %%
#Area of rectangel

def area_of_rect(len,brea):
  area_of_rect=len*brea
  print(f"Area of Rectangle : {area_of_rect}")
  return area_of_rect

len=12
brea=6

print("Area of Rectangle :",len, brea)
# Out:
# Area of Rectangle : 12 6

# %%
#without def

leng=12
brea=6
area_of_rectangel=leng*brea



print(f"Area of rectangle {area_of_rectangel}")
#print(int(input("Enter Lenght :" len)))
#print(int(input("Enter Breath :" brea)))
# Out:
# Area of rectangle 72

# %%
# With def



def area_of_rect(len,brea):
  print("Done")
  return "Area of rectangle :", len* brea





area_of_rect(10,5)
# Out:
# Done
# ('Area of rectangle :', 50)

# %%
# prime number

def prime(num):
  if num <=1:
    return 1

  for i in range (2, num):
    if num %i==0:
      return ("Number is not prime !")
    else:
      return ("Number is prime !")


prime(27)
prime(21)
prime(80)
prime(29)
prime(13)
prime(15)
prime(31)
# Out:
# 'Number is not prime !'

# %%
# prime number

def prime_num(num):
  if num <=1:
    return 1

  for i in range (2, num):
    if num %i==0:
      return ("Number is not prime !")
    else:
      return ("Number is prime !")

#num=int(input("enter :"))

prime_num(80)
# Out:
# 'Number is not prime !'
