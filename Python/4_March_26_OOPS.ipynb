# %% [markdown]
# <a href="https://colab.research.google.com/github/Gajendra182003/Big-Data-Analysis/blob/main/4_March_26_OOPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
syntax:
class <Name>:
    #class member
    #function member(self,parameters):
        self.members=local parameters

# %%
class Human:
    def birth(self,gender):
        print(f"self is {id(self)}")
        self.gender=gender
        print(f"gender set to {self.gender}")
        #self means object's who ever has called,variable that carry ref
    def set_name(self,name):
        self.name=name
        print(f"name set to {self.name}")
    def intro(self):
        print(f"hi i am {self.name} and i am a {self.gender}")

# %%
h=Human()#Object is created; only it has its methods and if some class member
#In Python instance members, that means objects own data will be created when methods are called. Like if a situation exists, a property will be created.

# %%
h.gender
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_221/3351239990.py in <cell line: 0>()
# ----> 1 h.gender
#
# AttributeError: 'Human' object has no attribute 'gender'

# %%
id(h)
# Out:
# 133249008701456

# %%
h.birth("male")
# Out:
# self is 133249008701456
# gender set to male

# %%
h.gender
# Out:
# 'male'

# %%
h.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_221/2737587261.py in <cell line: 0>()
# ----> 1 h.name
#
# AttributeError: 'Human' object has no attribute 'name'

# %%
h.set_name("amar")
# Out:
# name set to amar

# %%
h.intro()
# Out:
# hi i am amar and i am a male

# %%
h2=Human()
h2.birth("Female")
h2.gender
# Out:
# gender set to Female
# 'Female'

# %%
h2.intro()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_221/1087184376.py in <cell line: 0>()
# ----> 1 h2.intro()
#
# /tmp/ipykernel_221/629020204.py in intro(self)
#       8         print(f"name set to {self.name}")
#       9     def intro(self):
# ---> 10         print(f"hi i am {self.name} and i am a {self.gender}")
#
# AttributeError: 'Human' object has no attribute 'name'

# %%
Create a class Circle which has a method setRadius and another method printArea. The user will use setRadius to set the radius value and printArea to print the area of a circle.

# %%
class Circle:
    def set_radius(self,radius):
        self.radius=radius

    def print_area(self):
        print(f"Area is {3.14*self.radius**2}")

# %%
object=Circle()
r=float(input("Enter radius:"))
object.set_radius(r)
object.print_area()
# Out:
# Enter radius:55
# Area is 9498.5

# %%
Create a class calculator which has four methods:
- add
- multiply
- subtract
- divide
which is called with two data members and will print the appropriate result.
#sample:
object.add(10,20)--->print 10+20=30

# %%
class calculator:
    def add(self,no1,no2):
        print(f"{no1} + {no2} = {no1+no2}")
    def sub(self,no1,no2):
        print(f"{no1} - {no2} = {no1-no2}")
    def mul(self,no1,no2):
        print(f"{no1} * {no2} = {no1*no2}")
    def div(self,no1,no2):
        print(f"{no1} / {no2} = {no1/no2}")

# %%
obj=calculator()

# %%
obj.add(10,20)
obj.mul(10,20)
obj.sub(10,20)
obj.div(10,20)
# Out:
# 10 + 20 = 30
# 10 * 20 = 200
# 10 - 20 = -10
# 10 / 20 = 0.5

# %%
Create a class Time. Have a method setTime which sets HH:MM:SS
Also has a method display which will display time in hours minutes and seconds.
Create a class with methods:
- increase_hour
- increase_minute
- increase_second
which will respectively increase the given unit.

# %%
class Time:
    def set_time(self,h,m,s):
        self.h=h
        self.m=m
        self.s=s
        print(f"Time set to:{self.h}:{self.m}:{self.s}")
    def increase_hour(self):
        self.h+=1
        print(f"New time set to:{self.h}:{self.m}:{self.s}")
    def increase_minute(self):
        self.m+=1
        if self.m>=60:
            self.h+=1
            self.m=self.m%60
        print(f"New time set to:{self.h}:{self.m}:{self.s}")
    def increase_second(self):
        self.s+=1
        if self.s>=60:
            self.m+=1
            self.s=self.m%60
        print(f"New time set to:{self.h}:{self.m}:{self.s}")

# %%
t1=Time()
t2=Time()

# %%
t1.set_time(10,59,59)
# Out:
# Time set to:10:59:59

# %%
t1.increase_second()
# Out:
# New time set to:10:60:0

# %%
t1.increase_minute()
# Out:
# New time set to:11:1:0

# %%
class Human:
    def __init__(self):#Call on its own.
        print(f"init called:object created:{id(self)}")
    def birth(self,gender):
        self.gender=gender
        print(f"gender set to {self.gender}")
        #self means object's who ever has called,variable that carry ref
    def set_name(self,name):
        self.name=name
        print(f"name set to {self.name}")
    def intro(self):
        print(f"hi i am {self.name} and i am a {self.gender}")

# %%
h=Human()
# Out:
# init called:object created:133249068799936

# %%
h2=Human()
# Out:
# init called:object created:133249008577152

# %%
h3=Human()
# Out:
# init called:object created:133249008576144

# %%
#In it is a system method called on its own. Any system method in Python starts and ends with double underscore.   __method__()
class Human:
    def __init__(self,name,gender):#Call on its own.
        print(f"init called:object created:{id(self)}")
        self.gender=gender
        self.name=name
        print(f"name set to {self.name}")
        print(f"gender set to {self.gender}")
    def intro(self):
        print(f"hi i am {self.name} and i am a {self.gender}")

# %%
h=Human("amar","male")
# Out:
# init called:object created:133249008576432
# name set to amar
# gender set to male

# %%
h2=Human("amarita","female")
# Out:
# init called:object created:133249008700352
# name set to amarita
# gender set to female

# %%
class Human:
    def __init__(self,name="unnamed",gender="unknown"):#Call on its own.
        print(f"init called:object created:{id(self)}")
        self.gender=gender
        self.name=name
        print(f"name set to {self.name}")
        print(f"gender set to {self.gender}")
    def intro(self):
        print(f"hi i am {self.name} and i am a {self.gender}")

# %%
h=Human("amar","male")
h2=Human("amarita")
h3=Human()
# Out:
# init called:object created:133249008575328
# name set to amar
# gender set to male
# init called:object created:133249008576432
# name set to amarita
# gender set to unknown
# init called:object created:133249008700352
# name set to unnamed
# gender set to unknown

# %%
#__del__: Call on its own, just before the object is going to be permanently deleted, used to perform a last-minute task just before the object goes off, like closing an open file and leaving resources which you had.

# %%
class Human:
    def __init__(self,name="unnamed",gender="unknown"):#Call on its own.
        print(f"init called:object created:{id(self)}")
        self.gender=gender
        self.name=name
    def intro(self):
        print(f"hi i am {self.name} and i am a {self.gender}")
    def __del__(self):
        print(f"{self.name} R.I.P")

# %%
h1=Human("hritik","male")
h1.intro()
# Out:
# init called:object created:133249008761024
# hi i am hritik and i am a male

# %%
h1=Human("kangana","female")
# Out:
# init called:object created:133249008761888
# hritik R.I.P

# %%
del h1
# Out:
# kangana R.I.P

# %%
#Del is not written. Still the object will go for AGC. If del is written then before going for AGC del will be called at the last moment.

# %%
#Array of objects / multiple objects of the similar type in a list or a dictionary. Maximum use in projects.
1. Unique numbering using class member
2. Accepting multiple objects in a list or dictionary

# %%
#Class member only exists with the class. Hence call only with class.member. Although objects can directly access, advise not to do so.
class Human:
    population=0#This is a member of a class and can be accessed by other objects but there exists only a single copy available with the class itself.
    def __init__(self,name="unnamed",gender="unknown"):#Call on its own.
        self.gender=gender
        self.name=name
        Human.population+=1
        print(f"New human {self.name} is created Total population is {Human.population}")
    def intro(self):
        print(f"hi i am {self.name} and i am a {self.gender}")
    def __del__(self):
        Human.population-=1
        print(f"R.I.P {self.name} is deleted: Total population is {Human.population}")

# %%
h1=Human("amar","male")
h2=Human("samar","male")
h3=Human("tamar","male")
h4=Human("uamar","male")
# Out:
# New human amar is created Total population is 1
# New human samar is created Total population is 2
# New human tamar is created Total population is 3
# New human uamar is created Total population is 4

# %%
del h2
# Out:
# R.I.P samar is deleted: Total population is 3

# %%
h1=Human("amarita","female")
# Out:
# New human amarita is created Total population is 4
# R.I.P amar is deleted: Total population is 3

# %%
class Account:
    account_number_generator=202600
    def __init__(self,name,amount):
        self.name=name
        self.amount=amount
        Account.account_number_generator+=1
        self.account_number=Account.account_number_generator
        print(f"Account successfully created. Your account number is {self.account_number}")

# %%
a1=Account("amar",12000)
# Out:
# Account successfully created. Your account number is 202601

# %%
a2=Account("amarita",120000)
# Out:
# Account successfully created. Your account number is 202602

# %%
a3=Account("chintu",1200)
# Out:
# Account successfully created. Your account number is 202603

# %%
We are implementing a complete banking system. A user can:
- open an account
- withdraw from the account
- deposit to an account
- check the balance from the account
# Out:
#   File "/tmp/ipykernel_221/2360299636.py", line 1
#     We are implementing a complete banking system. A user can:
#        ^
# SyntaxError: invalid syntax

# %%
class Account:
    account_number_generator=202600
    def __init__(self,name,amount):
        self.name=name
        self.amount=amount
        Account.account_number_generator+=1
        self.account_number=Account.account_number_generator
        print(f"Account successfully created. Your account number is {self.account_number}")
    def check_balance(self):
        print(f"your account_number:{self.account_number} has {self.amount}. ")
    def deposite(self,amount):
        if amount>0:
            self.amount+=amount
            self.check_balance()
        else:
            print(f"{amount} not be negative.")
    def withdraw(self,amount):
        if self.amount-amount>3000:
            self.amount-=amount
            self.check_balance()
        else:
            print(f"Low balance, hence transaction cannot be performed")
    def get_account(self):
        return self.account_number

# %%
a1=Account("amar",10000)
# Out:
# Account successfully created. Your account number is 202601

# %%
a1.check_balance()
# Out:
# your account_number:202601 has 10000.

# %%
a1.deposite(-10000)
# Out:
# -10000 not be negative.

# %%
a1.deposite(10000)
# Out:
# your account_number:202601 has 20000.

# %%
a1.withdraw(100000)
# Out:
# Low balance, hence transaction cannot be performed

# %%
a1.withdraw(100)
# Out:
# your account_number:202601 has 9900.

# %%
bank={}
#Account to the bank(dict)

# %%
bank[a1.get_account()]=a1

# %%
a2=Account("amarita",100000)
a3=Account("samar",1000)
# Out:
# Account successfully created. Your account number is 202602
# Account successfully created. Your account number is 202603

# %%
bank[a2.get_account()]=a2

# %%
bank[a3.get_account()]=a3

# %%
bank
# Out:
# {202601: <__main__.Account at 0x793073d835f0>,
#  202602: <__main__.Account at 0x793073d80da0>,
#  202603: <__main__.Account at 0x793073d56330>}

# %%
for account_number in bank:
    bank[account_number].check_balance()
#bank[account_number]: gives the object account(object)and .method can be activated.
# Out:
# your account_number:202601 has 9900.
# your account_number:202602 has 100000.
# your account_number:202603 has 1000.

# %%
bank[202603].deposite(5000)
# Out:
# your account_number:202603 has 6000.

# %%
#withdraw 2,000 from account number 202602.
bank[202602].withdraw(2000)
# Out:
# your account_number:202602 has 98000.

# %%
bank={}
class Account:
    account_number_generator=202600
    def __init__(self,name,amount):
        self.name=name
        self.amount=amount
        Account.account_number_generator+=1
        self.account_number=Account.account_number_generator
        print(f"Account successfully created. Your account number is {self.account_number}")
    def check_balance(self):
        print(f"your account_number:{self.account_number} has {self.amount}. ")
    def deposite(self,amount):
        if amount>0:
            self.amount+=amount
            self.check_balance()
        else:
            print(f"{amount} not be negative.")
    def withdraw(self,amount):
        if self.amount-amount>3000:
            self.amount-=amount
            self.check_balance()
        else:
            print(f"Low balance, hence transaction cannot be performed")
    def get_account(self):
        return self.account_number

def menu():
    print(f'''\n{"".center(30,'-')}''')
    print("LENA BANK".center(30))
    print(f'''{"".center(30,'-')}''')
    print("1.Create Account")
    print("2.Deposite")
    print("3.Withdraw")
    print("4.Check Balance")
    #Fifth option: Account Transfer, where the user has to give the source account, destination account, and transfer money from the source account to the destination account, checking the minimum balance option.
    print("0.Exit")
    print(f'''{"".center(30,'-')}''')

choice=0
while True:
    menu()
    choice=int(input(":"))
    if choice==1:
        #An account only if 5,000 or 5,000+ is given.
        name=input("Enter Name:")
        while True:
            amount=float(input("Enter Amount"))
            if amount>=5000:
                a=Account(name,amount)
                break
            else:
                print("To open an account one needs a minimum of 5,000.")
        bank[a.get_account()]=a
    elif choice==2:
        account=int(input("Enter account number:"))
        if account in bank:
            print("{account} found...")
            bank[account].deposite(float(input("Enter amount:")))
        else:
            print("{account} not found...")
    elif choice==3:
        account=int(input("Enter account number:"))
        if account in bank:
            print("{account} found...")
            bank[account].withdraw(float(input("Enter amount:")))
        else:
            print("{account} not found...")
    elif choice==4:
        account=int(input("Enter account number:"))
        if account in bank:
            print("{account} found...")
            bank[account].check_balance()
        else:
            print("{account} not found...")
    elif choice==0:
        print("Thank you for banking with us.")
        break
    else:
        print("Selected option is invalid.")
# Out:
# ------------------------------
#           LENA BANK
# ------------------------------
# 1.Create Account
# 2.Deposite
# 3.Withdraw
# 4.Check Balance
# 0.Exit
# ------------------------------
# :1
# Enter Name:amar
# Enter Amount2000
# To open an account one needs a minimum of 5,000.
# Enter Amount4000
# To open an account one needs a minimum of 5,000.
# Enter Amount4500
# To open an account one needs a minimum of 5,000.
# Enter Amount5001
# Account successfully created. Your account number is 202601
#
# ------------------------------
#           LENA BANK
# ------------------------------
# 1.Create Account
# 2.Deposite
# 3.Withdraw
# 4.Check Balance
# 0.Exit
# ------------------------------
# :0
# Thank you for banking with us.

# %%
# Out:
# ------------------------------
#           LENA BANK
# ------------------------------
# 1.Create Account
# 2.Deposite
# 3.Withdraw
# 4.Check Balance
# 0.Exit
# ------------------------------

# %%
Abstraction is hiding and giving simple access. What is hiding? Complex implementation detail because the user is not interested; neither should he know.
public:
<var>:default
Accessible by anyone from anywhere

private:
_<var>
Not accessible because not reflected but if known, someone can access.

strong private:
__<var>
Access Apple only by the member of class within the class. Outsider cannot have access.

# %%
class Person:
    gender="male"
    _name="amar"
    __phonenumber="9821601163"
    def get_number(self):#Leaking method, a method which will leak out information from inside to outside.:<Vibhishan>
        return Person.__phonenumber

# %%
Person.gender
# Out:
# 'male'

# %%
Person._name
# Out:
# 'amar'

# %%
Person.__phonenumber
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_221/2257597535.py in <cell line: 0>()
# ----> 1 Person.__phonenumber
#
# AttributeError: type object 'Person' has no attribute '__phonenumber'

# %%
p=Person()
p.get_number()
# Out:
# '9821601163'

# %%
A general thumb rule is:
- Data are made strong private.
- Functions are made public.
Strong private data are accessed via public function,
a complete set of encapsulation and abstraction.

# %%
class A:
    pass
class B(A):
    pass

# %%
class A:
    def myA(self):
        print("Hi from A My_A")
class B:
    def myB(self):
        print("Hi from B My_B")

# %%
obj_b=B()

# %%
obj_b.myB()
# Out:
# Hi from B My_B

# %%
class A:
    def myA(self):
        print("Hi from A My_A")
class B(A):#Inherit everything from it from A
    def myB(self):
        print("Hi from B My_B")

# %%
obj_b=B()

# %%
obj_b.myB()
obj_b.myA()
# Out:
# Hi from B My_B
# Hi from A My_A

# %%
class Parent:
    def welcome(self,name):
        print("Parent: welcome,",name)
    def food(self):
        print("Parent:roti sabji...")
class Child(Parent):
    pass

# %%
obj=Child()

# %%
obj.welcome("amar")
# Out:
# Parent: welcome, amar

# %%
obj.food()
# Out:
# Parent:roti sabji...

# %%
#Override. : A child re-writes parent's method. It will reject inheritance and will consider its own method as a new method. This concept is called overriding parent method and creating your own.
#With reference to the change in time requirement and process, it might change hence we might override old methods with the new one.
class Parent:
    def welcome(self,name):
        print("Parent: welcome,",name)
    def food(self):
        print("Parent:roti sabji...")
class Child(Parent):
    def food(self):#override
        print("CHILD      Pizza Burger....")

# %%
obj=Child()

# %%
obj.welcome("amar")
# Out:
# Parent: welcome, amar

# %%
obj.food()
# Out:
# CHILD      Pizza Burger....

# %%
#Polymorphism is the ability to exist in multiple forms.
1. Function overloading: exact function capable of handling different types of queries and giving different answers.happens within class
2. Overriding happens between parent and child, where the parent's method is rewritten by the child.happens accross parent and child

# %%
#By default Python functions are overloaded to support multiple data types. That means because of dynamic casting it can support any operation depending on what data is being passed without writing multiple times for different data types.
#Overloading means one function capable of supporting multiple activities or multiple data types.
#Example:you  son, friend, trainer, Founder, in some cases co-founder.
def add(p1,p2):
    print(f"{type(p1)},{type(p2)}")
    print(f"{p1}+{p2}={p1+p2}")

# %%
add(10,20)
add(5.1,1)
add(100,8.9)
add("amar ","Panchal")
# Out:
# <class 'int'>,<class 'int'>
# 10+20=30
# <class 'float'>,<class 'int'>
# 5.1+1=6.1
# <class 'int'>,<class 'float'>
# 100+8.9=108.9
# <class 'str'>,<class 'str'>
# amar +Panchal=amar Panchal

# %%
class A:
    def my(self):
        print("Hi from A My_A")
class B:
    def my(self):
        print("Hi from B My_B")
class C:
    def my(self):
        print("Hi from C My_C")
class X:
    def myX(self):
        print("Hi from X My_X")

# %%
obj=X()

# %%
obj.myX()
# Out:
# Hi from X My_X

# %%
#mutilevel
class A:
    def my_A(self):
        print("Hi from A My_A")
class B(A):
    def my_B(self):
        print("Hi from B My_B")
class C(B):
    def my_C(self):
        print("Hi from C My_C")
class X(C):
    def my_X(self):
        print("Hi from X My_X")

# %%
obj=X()

# %%
obj.

# %%
#Hierarchical
class A:
    def my_A(self):
        print("Hi from A My_A")
class B(A):
    def my_B(self):
        print("Hi from B My_B")
class C(A):
    def my_C(self):
        print("Hi from C My_C")
class X(A):
    def my_X(self):
        print("Hi from X My_X")

# %%
#Multiple inheritance. Python supports this.
#Multiple superclasses deriving one subclass is multiple inheritance. Tricky because of the ambiguity existing, handled by the first come first taken principle.

Mutiple:

issue:
ambiguity
Two or more superclasses have exactly one method. Whose method should we inherit?

# %%
#People inheritance A and B are inherited by X.
class A:
    def my_A(self):
        print("Hi from A My_A")
class B:
    def my_B(self):
        print("Hi from B My_B")
class X(A,B):
    def my_X(self):
        print("Hi from X My_X")

# %%
obj=X()

# %%
obj.

# %%
Mutiple:

issue:
ambiguity
Two or more superclasses have exactly one method. Whose method should we inherit?

# %%
#People inheritance A and B are inherited by X.
class A:
    def my(self):
        print("Hi from A My_A")
class B:
    def my(self):
        print("Hi from B My_B")
class X(B,A):#Ambiguity is resolved by first-come, first-Taken
    def my_X(self):
        print("Hi from X My_X")

# %%
obj=X()
obj.my_X()
obj.my()
# Out:
# Hi from X My_X
# Hi from B My_B

# %%
#__str__(): This method is automatically called when the object is in a print statement, used to create a proper formatted print directly callable from the print statement itself.
#Would return string for printing Will not print. (only string)

# %%
class Human:
    def __init__(self,name,gender):#Call on its own.
        print(f"init called:object created:{id(self)}")
        self.gender=gender
        self.name=name
        print(f"name set to {self.name}")
        print(f"gender set to {self.gender}")
    def __str__(self):
        return f"hi i am {self.name} and i am a {self.gender}"

# %%
h=Human("amar","male")
# Out:
# init called:object created:133249007540832
# name set to amar
# gender set to male

# %%
print(h)
#Object is directly printed. It will first search for STR implementation. If not found, it will simply give a reference to that object.
# Out:
# hi i am amar and i am a male

# %%
#Create a class voter. This would have:
- name
- age
Initialize using the init method whenever the object is created. When printing is called it will print name and age and can vote if above 18; will print name and age and cannot vote if below 18.

# %%
class Voter:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        print("\n Age and name set")
    def __str__(self):
        if self.age<18:
            return f"hi {self.name} you can not vote at age {self.age}"
        else:
            return f"hi {self.name} you can vote at age {self.age}"

# %%
v=Voter("superman",36)
print(v)
# Out:
#  Age and name set
# hi superman you can vote at age 36

# %%
v=Voter("spiderman",6)
print(v)
# Out:
#  Age and name set
# hi spiderman you can not vote at age 6

# %%
#super(): in Python when a base class object is created, the superclass object is not called. The superclass constructor or init method is not called. If we want to have a call to a superclass method, we use the super method for doing it.
class A:
    def __init__(self):
        print("Hi from A My_A")
class B(A):
    def __init__(self):
        super().__init__()
        print("Hi from B My_B")

# %%
a=A()
# Out:
# Hi from A My_A

# %%
b=B()
# Out:
# Hi from A My_A
# Hi from B My_B

# %%
#Can be used to pass data to parent classes and grandparent classes.
class A:
    def __init__(self,data):
        print(f"Hi from A My_A : data given:{data}")
class B(A):
    def __init__(self,data1,data2,data3):
        super().__init__(data1)
        print(f"Hi from B My_B {data2} {data3}")

# %%
b=B(10,300,6000)
# Out:
# Hi from A My_A : data given:10
# Hi from B My_B 300 6000

# %%
class A:
    def __init__(self):
        print("Initializing A")

class B(A):
    def __init__(self):
        print("Initializing B")
        super().__init__()

class C(A):
    def __init__(self):
        print("Initializing C")
        super().__init__()

class D(B, C):
    def __init__(self):
        print("Initializing D")
        super().__init__()

# Instantiate D
d = D()
#It is thanks to MRO method resolution order.
#These in it are called:
'''
1. When super is initiated, the first super class B is called.
2. The second super class C is called.
3. From B and C, their super class A is called.'''
# Out:
# Initializing D
# Initializing B
# Initializing C
# Initializing A

# %%
#create human:has gender ,name
# education : has degree
# job: has salary
#using __init__() set all values and print them from job only
#accept parameters in job only but set in respective class

# %%
class Human:
    def __init__(self, name, gender):
        self.name = name
        self.gender = gender
        print("name,gender set in Human")

class Education(Human):
    def __init__(self, name,gender,degree):
        super().__init__(name,gender)
        self.degree = degree
        print("degree set in Education")

class Job(Education):
    def __init__(self, name, gender, degree, salary):
        super().__init__(name, gender,degree)
        self.salary = salary
        print("salary set in Job ")

    def display(self):
        print(f"Name: {self.name}")
        print(f"Gender: {self.gender}")
        print(f"Degree: {self.degree}")
        print(f"Salary: {self.salary}")

employee = Job("Amit", "Male", "B.Tech", 60000)
employee.display()
# Out:
# name,gender set in Human
# degree set in Education
# salary set in Job
# Name: Amit
# Gender: Male
# Degree: B.Tech
# Salary: 60000
